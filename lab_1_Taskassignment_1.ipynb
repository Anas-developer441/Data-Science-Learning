# %% [markdown]
# <a href="https://colab.research.google.com/github/Anas-developer441/Data-Science-Learning/blob/main/lab_1_Taskassignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
length = 4
width = 5
Area = length * width
print(Area)
# Out:
# 20

# %%
celsius = 25
Fahrenheit = (celsius * 9/5) + 32
print(Fahrenheit)
# Out:
# 77.0

# %%
#Task 3: The Hypotenuse (Pythagorean Theorem)

a = 3
b = 4
c = (a**2 + b**2)**0.5
print(c)
# Out:
# 5.0

# %%
#Task 4: Circle Geometry
radius = 7
pi = 3.14159
Area = (pi*radius**2)
print(Area)
# Out:
# 153.93791

# %%
#Task 5: Tip Calculator (Modulo Practice)
total_bill = 100
number_of_people = 3
Remainder = (total_bill % number_of_people)
print(Remainder)
# Out:
# 1

# %%
#Task 6: Floor Division (The "Baker's" Problem)
total_cookies = 22
box_capacity = 5
Full_Boxes = (total_cookies // box_capacity)
print(Full_Boxes)
# Out:
# 4

# %%
#Task 7: Compound Interest
p = 1000
r = 0.05
t = 3
A=(p*(1+r)**t)
print(A)
# Out:
# 1157.6250000000002
