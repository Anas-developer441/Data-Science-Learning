# %%
# sql lite

# %%
# !pip install ipython-sql sqlalchemy
# Out:
# Requirement already satisfied: ipython-sql in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlalchemy in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (2.0.51)
# Requirement already satisfied: prettytable in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (3.18.0)
# Requirement already satisfied: ipython in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (9.14.1)
# Requirement already satisfied: sqlparse in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.5.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.15.1)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from prettytable->ipython-sql) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.18.2->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install ipython-sql sqlalchemy
# Out:
# Collecting ipython-sql
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.51-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Collecting prettytable (from ipython-sql)
#   Using cached prettytable-3.18.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: ipython in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (9.12.0)
# Collecting sqlparse (from ipython-sql)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.2-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from jedi>=0.18.2->ipython->ipython-sql) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\rafi khawar\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading sqlalchemy-2.0.51-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.4 MB/s  0:00:01
# Downloading greenlet-3.5.2-cp314-cp314-win_amd64.whl (240 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached prettytable-3.18.0-py3-none-any.whl (37 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, greenlet, sqlalchemy, ipython-sql
#
#    ------ --------------------------------- 1/6 [sqlparse]
#    ------ --------------------------------- 1/6 [sqlparse]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    ---------------------------------------- 6/6 [ipython-sql]
#
# Successfully installed greenlet-3.5.2 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.18.0 sqlalchemy-2.0.51 sqlparse-0.5.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Rafi Khawar\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
import dtale

# This opens a fully interactive workbench grid right inside your notebook!
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-91VC00F:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install ipython-sql pymysql sqlalchemy
# Out:
# Requirement already satisfied: ipython-sql in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (0.5.0)
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sqlalchemy in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (2.0.51)
# Requirement already satisfied: prettytable in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (3.18.0)
# Requirement already satisfied: ipython in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (9.14.1)
# Requirement already satisfied: sqlparse in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.5.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.15.1)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from prettytable->ipython-sql) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.18.2->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\rafi khawar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql

# %%
# %%sql
# SELECT @@version;
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 1 rows affected.
# [('8.0.46',)]

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS customer_feedback(
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     customer_name VARCHAR(50) NOT NULL,
#     email VARCHAR(100) NOT NULL,
#     rating INT NOT NULL CHECK(rating BETWEEN 1 AND 5),
#     comment VARCHAR(255),
#     submission_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     issue_type VARCHAR(50)
#     );
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO customer_feedback (customer_name, email, rating, comment, submission_date, issue_type) VALUES
# ('Anas Rafi', 'anasark441@gmail.com', 5, 'Fast delivery and great packaging!', '2023-10-01', 'Delivery'),
# ('Sarah Jenkins', 'sarah.j@example.com', 2, 'Item arrived damaged.', '2023-10-02', 'Product'),
# ('Tiffany Lee', 'tiffany.l@example.com', 4, 'Good product, but late response from support.', '2023-10-03', 'Support'),
# ('Mike Ross', 'mike.r@example.com', 1, 'Terrible experience. Wrong item sent.', '2023-10-05', 'Product'),
# ('Tanya Foy', 'tanya.f@example.com', 5, 'Best customer service ever!', '2023-10-06', 'Support'),
# ('Alice Wong', 'alice.w@example.com', 3, 'Average quality, expected better.', '2023-10-07', 'Product'),
# ('Tommy Hill', 'tommy.h@example.com', 4, 'Quick refund process.', '2023-10-08', 'Billing'),
# ('France User', 'france.u@example.com', 2, 'Delivery was delayed by a week.', '2023-10-10', 'Delivery'),
# ('Toby Mac', 'toby.m@example.com', 1, 'Rude support agent.', '2023-10-12', 'Support'),
# ('Linda Green', 'linda.g@example.com', 5, 'Will definitely buy again.', '2023-10-15', 'Product');
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 10 rows affected.
# []

# %%
# %%sql
# SELECT * FROM customer_feedback WHERE rating = 5;
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 3 rows affected.
# [(1, 'Anas Rafi', 'anasark441@gmail.com', 5, 'Fast delivery and great packaging!', datetime.datetime(2023, 10, 1, 0, 0), 'Delivery'),
#  (5, 'Tanya Foy', 'tanya.f@example.com', 5, 'Best customer service ever!', datetime.datetime(2023, 10, 6, 0, 0), 'Support'),
#  (10, 'Linda Green', 'linda.g@example.com', 5, 'Will definitely buy again.', datetime.datetime(2023, 10, 15, 0, 0), 'Product')]

# %%
# %%sql
# SELECT * FROM customer_feedback WHERE customer_name='Tiffany Lee' AND rating >=4;
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 1 rows affected.
# [(3, 'Tiffany Lee', 'tiffany.l@example.com', 4, 'Good product, but late response from support.', datetime.datetime(2023, 10, 3, 0, 0), 'Support')]

# %%
# %%sql
# SELECT * FROM customer_feedback WHERE submission_date>'2023-10-05' AND rating > 3;
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 3 rows affected.
# [(5, 'Tanya Foy', 'tanya.f@example.com', 5, 'Best customer service ever!', datetime.datetime(2023, 10, 6, 0, 0), 'Support'),
#  (7, 'Tommy Hill', 'tommy.h@example.com', 4, 'Quick refund process.', datetime.datetime(2023, 10, 8, 0, 0), 'Billing'),
#  (10, 'Linda Green', 'linda.g@example.com', 5, 'Will definitely buy again.', datetime.datetime(2023, 10, 15, 0, 0), 'Product')]

# %%
# %%sql
# SELECT *FROM customer_feedback WHERE rating =5 AND (customer_name='Anas Rafi' OR customer_name= 'Tanya Foy')
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 2 rows affected.
# [(1, 'Anas Rafi', 'anasark441@gmail.com', 5, 'Fast delivery and great packaging!', datetime.datetime(2023, 10, 1, 0, 0), 'Delivery'),
#  (5, 'Tanya Foy', 'tanya.f@example.com', 5, 'Best customer service ever!', datetime.datetime(2023, 10, 6, 0, 0), 'Support')]

# %%
# %%sql
# SELECT customer_name, comment FROM customer_feedback WHERE customer_name LIKE 'T%y';
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 1 rows affected.
# [('Tanya Foy', 'Best customer service ever!')]

# %%
# %%sql
# SELECT *FROM customer_feedback WHERE issue_type IN('Product','Billing');
# Out:
#  * mysql+pymysql://root:***@localhost/anasdb
# 5 rows affected.
# [(2, 'Sarah Jenkins', 'sarah.j@example.com', 2, 'Item arrived damaged.', datetime.datetime(2023, 10, 2, 0, 0), 'Product'),
#  (4, 'Mike Ross', 'mike.r@example.com', 1, 'Terrible experience. Wrong item sent.', datetime.datetime(2023, 10, 5, 0, 0), 'Product'),
#  (6, 'Alice Wong', 'alice.w@example.com', 3, 'Average quality, expected better.', datetime.datetime(2023, 10, 7, 0, 0), 'Product'),
#  (7, 'Tommy Hill', 'tommy.h@example.com', 4, 'Quick refund process.', datetime.datetime(2023, 10, 8, 0, 0), 'Billing'),
#  (10, 'Linda Green', 'linda.g@example.com', 5, 'Will definitely buy again.', datetime.datetime(2023, 10, 15, 0, 0), 'Product')]
